# %%
# !pip install rdkit

# %%
from rdkit import rdBase
from rdkit import Chem

# %%
m = Chem.MolFromSmiles('Cc1ccccc1')

# %%
m

# %%
m_2 = Chem.MolFromSmiles('CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H]3[C@H]1C5')

# %%
m_2
